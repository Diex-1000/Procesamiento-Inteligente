# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
df_diabetes = load_diabetes()

# %%
x = df_diabetes.data[:,2].reshape(-1,1)
y = df_diabetes.target

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = regressor.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error, r2_score

print('Coefficients: \n', regressor.coef_)
print('Independent term: \n', regressor.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(Y_train, Y_pred))
# Out:
# Coefficients:
#  [1013.17358257]
# Independent term:
#  153.43509039227231
# Mean squared error: 3892.72

# %%
print(regressor.score(X_test, Y_test))
print("Variance score: %.2f" % r2_score(Y_train, Y_pred))
# Out:
# 0.23132831307953805
# Variance score: 0.38

# %%
sns.set_theme()
fig, ax = plt.subplots(1, 2, figsize=(10, 10), sharey=True)

ax[0].scatter(X_train, Y_train)
ax[0].plot(X_train, regressor.predict(X_train), c='g')
ax[0].set_title('Linear Regression')
ax[0].set_xlabel('Feature')
ax[0].set_ylabel('Target')

ax[1].scatter(X_test, Y_test)
ax[1].plot(X_train, regressor.predict(X_train), c='g')
ax[1].set_title('Linear Regression')
ax[1].set_xlabel('Feature')
ax[1].set_ylabel('Target')

plt.suptitle('Linear Regression Model')
# Out:
# Text(0.5, 0.98, 'Linear Regression Model')

# %%
xx = df_diabetes.data[:, [2, 3]]
yy = df_diabetes.target

X_train, X_test, Y_train, Y_test = train_test_split(xx, yy, test_size=0.3, random_state=0)

regressor = LinearRegression()
regressor.fit(X_train, Y_train)
regressor.score(X_test, Y_test)
# Out:
# 0.30926378323611403

# %% [markdown]
# # Conclusion

# %% [markdown]
# En este ejercicio se aplicó un modelo de regresión lineal para analizar la relación entre el IMC y la progresión de la diabetes, siguiendo un proceso ordenado de selección de variables, división de datos en entrenamiento y prueba, entrenamiento del modelo y evaluación de su desempeño. Este enfoque permite obtener resultados más confiables y refuerza la importancia de utilizar correctamente las herramientas y la documentación de Scikit-Learn.
