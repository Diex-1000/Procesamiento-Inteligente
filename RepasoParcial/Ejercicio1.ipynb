# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("../data/hotel.csv")

# %%
data.shape
# Out:
# (25, 3)

# %%
data.head()
# Out:
#    Dia  Ingreso  Habitaciones_ocupadas
# 0    1     1452                     23
# 1    2     1361                     47
# 2    3     1426                     21
# 3    4     1470                     39
# 4    5     1456                     37

# %%
X_train = np.array(data['Habitaciones_ocupadas']).reshape(-1,1)
Y_train = np.array(data['Ingreso'])

# %%
r = linear_model.LinearRegression()
r.fit(X_train, Y_train)
y_pred = r.predict(X_train)

print('Coeficiente de correlacion: ', r.coef_)
print('Interseccion: ', r.intercept_)
print('Error cuadratico de la media', mean_squared_error(Y_train, y_pred))
print('Varianza: ', r2_score(Y_train, y_pred))
# Out:
# Coeficiente de correlacion:  [1.47826909]
# Interseccion:  1381.987528344671
# Error cuadratico de la media 1443.6120256991696
# Varianza:  0.17891046848627656

# %%
x = X_train.ravel()
plt.figure(figsize=(8,5))
plt.scatter(x, Y_train, color='steelblue', s=80, label='Datos')
plt.plot(x, y_pred, color='red', linewidth=3, label='Pendiente')
plt.xlabel('Habitaciones ocupadas')
plt.ylabel('Ingresos')
plt.title('Hotel Suburbios')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# 1.  Interpretación de la gráfica de correlación:
#     La gráfica muestra una relación positiva débil entre las habitaciones ocupadas y el ingreso del restaurante, ya que la pendiente es pequeña y los puntos están bastante dispersos. El valor de R² ≈ 0.18 indica que solo el 18% de la variación en los ingresos se explica por las habitaciones ocupadas.
#
# 2. Comprobación con la fórmula de correlación:
#     Al calcular la correlación se obtiene un coeficiente positivo bajo, lo que confirma que la relación existe pero es débil. Esto valida el análisis visual observado en la gráfica.
